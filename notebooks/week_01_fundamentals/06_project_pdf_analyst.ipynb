# %% [markdown]
# <a href="https://colab.research.google.com/github/takzen/financial-ai-engineering-showcase/blob/main/notebooks/week_01_fundamentals/06_project_pdf_analyst.ipynb" target="_parent">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 📄 Tydzień 1, Dzień 6: Projekt - PDF Financial Analyst (Gemini Edition)
#
# To finałowy projekt pierwszego tygodnia. Zbudujemy pipeline AI typu "End-to-End".
# Nasz program będzie czytał dokumenty (PDF) i pisał z nich raporty inwestycyjne.
#
# **Cele na dziś:**
# 1.  **PDF Parsing:** Wyciąganie tekstu z dokumentów (`pypdf`).
# 2.  **Google Gemini API:** Łączenie się z modelem `gemini-2.5-flash`.
# 3.  **Prompt Engineering:** Nadawanie modelowi roli "Senior Analyst".
# 4.  **Generowanie Danych:** Stworzenie fikcyjnego raportu do testów.
#
# ---
# ### 🛠️ 1. Instalacja
#
# Potrzebujemy:
# *   `langchain-google-genai`: Obsługa modelu Gemini.
# *   `pypdf`: Czytanie PDF.
# *   `reportlab`: Generowanie PDF (dane testowe).

# %%
# !uv add langchain-google-genai pypdf reportlab python-dotenv

# %% [markdown]
# ### 📝 2. Generowanie Danych (Fikcyjny Raport)
#
# Stworzymy własny plik PDF z wynikami fikcyjnej spółki **"FutureCorp Inc."**.
# Zapiszemy go w folderze `data/reports`.

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
import os

# Ścieżki: notebooks/week_01 -> notebooks -> project -> data -> reports
current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, "../../"))
reports_dir = os.path.join(project_root, "data", "reports")
os.makedirs(reports_dir, exist_ok=True)

pdf_path = os.path.join(reports_dir, "financial_report_q3.pdf")

def create_dummy_pdf(filename):
    c = canvas.Canvas(filename, pagesize=A4)
    
    # Nagłówek
    c.setFont("Helvetica-Bold", 20)
    c.drawString(50, 800, "FutureCorp Inc. - Q3 2024 Financial Report")
    
    # Treść
    c.setFont("Helvetica", 12)
    text_lines = [
        "Date: October 25, 2024",
        "Sector: Technology / AI Hardware",
        "",
        "Executive Summary:",
        "FutureCorp delivered strong results this quarter, driven by unprecedented demand",
        "for our generative AI chips. Revenue grew by 45% YoY to $12.5 billion.",
        "However, operating expenses increased significantly due to R&D investments.",
        "",
        "Key Metrics:",
        "- Revenue: $12.5B (up 45% YoY)",
        "- Net Income: $3.2B (up 12% YoY)",
        "- EPS: $2.45",
        "",
        "Risks & Challenges:",
        "Supply chain constraints remain a bottleneck. Geopolitical tensions in Asia",
        "could impact our semiconductor fabrication partners.",
        "Additionally, a new lawsuit from a competitor regarding patent infringement",
        "could result in fines up to $500M.",
        "",
        "Outlook:",
        "We expect Q4 revenue to be flat due to seasonal adjustments."
    ]
    
    y = 750
    for line in text_lines:
        c.drawString(50, y, line)
        y -= 20
        
    c.save()
    print(f"✅ Wygenerowano raport: {filename}")

create_dummy_pdf(pdf_path)

# %% [markdown]
# ### 📖 3. PDF Parsing (Ekstrakcja Tekstu)
#
# LLM widzi tekst, nie pliki. Użyjemy `pypdf`, aby zamienić plik binarny na stringa.

# %%
from pypdf import PdfReader

def extract_text_from_pdf(pdf_path):
    """Czyta tekst z pliku PDF strona po stronie."""
    try:
        reader = PdfReader(pdf_path)
        text = ""
        for page in reader.pages:
            text += page.extract_text() + "\n"
        return text
    except Exception as e:
        return f"Error reading PDF: {e}"

# Testujemy
raw_text = extract_text_from_pdf(pdf_path)

print("--- TREŚĆ PLIKU PDF ---")
print(raw_text)
# Out:
# --- TREŚĆ PLIKU PDF ---
# FutureCorp Inc. - Q3 2024 Financial Report
# Date: October 25, 2024
# Sector: Technology / AI Hardware
# Executive Summary:
# FutureCorp delivered strong results this quarter, driven by unprecedented demand
# for our generative AI chips. Revenue grew by 45% YoY to $12.5 billion.
# However, operating expenses increased significantly due to R&D investments.
# Key Metrics:
# - Revenue: $12.5B (up 45% YoY)
# - Net Income: $3.2B (up 12% YoY)
# - EPS: $2.45
# Risks & Challenges:
# Supply chain constraints remain a bottleneck. Geopolitical tensions in Asia
# could impact our semiconductor fabrication partners.
# Additionally, a new lawsuit from a competitor regarding patent infringement
# could result in fines up to $500M.
# Outlook:
# We expect Q4 revenue to be flat due to seasonal adjustments.

# %% [markdown]
# ### 🧠 4. Analityk AI (Gemini 2.5 Flash)
#
# Teraz najważniejsza część. Wyślemy ten tekst do modelu Google.
# Używamy `ChatGoogleGenerativeAI` z modelem **gemini-2.5-flash**.

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

# Ładowanie klucza
load_dotenv(os.path.join(project_root, ".env"))

if not os.getenv("GOOGLE_API_KEY"):
    print("❌ BŁĄD: Brak klucza Google API w .env")
else:
    print("✅ Klucz Google załadowany.")

# Konfiguracja modelu
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0  # Zero kreatywności, chcemy fakty
)
# Out:
# ✅ Klucz Google załadowany.

# %%
def analyze_report(report_text):
    """Wysyła tekst raportu do AI i zwraca analizę."""
    
    # Prompt Systemowy (Rola)
    system_prompt = """
    Jesteś Starszym Analitykiem Inwestycyjnym (Senior CFA). 
    Twoim zadaniem jest analiza tekstu raportu finansowego.
    
    Przygotuj zwięzłe podsumowanie w języku POLSKIM zawierające:
    1. 🟢 Główne sukcesy (Revenue, Growth).
    2. 🔴 Główne ryzyka (Risks, Supply Chain, Lawsuits).
    3. ⚖️ Werdykt inwestycyjny (Jedno zdanie: Bullish/Bearish/Neutral).
    """
    
    # Prompt Użytkownika (Dane)
    user_prompt = f"Oto treść raportu:\n\n{report_text}"
    
    print("🤖 Analityk AI (Gemini) pracuje...")
    
    try:
        # LangChain obsługuje formatowanie listy wiadomości
        response = llm.invoke([
            ("system", system_prompt),
            ("human", user_prompt)
        ])
        return response.content
    except Exception as e:
        return f"Błąd API: {e}"

# Uruchomienie
analysis = analyze_report(raw_text)

print("\n" + "="*50)
print("📊 RAPORT ANALITYCZNY AI")
print("="*50)
print(analysis)
# Out:
# 🤖 Analityk AI (Gemini) pracuje...
#
# ==================================================
# 📊 RAPORT ANALITYCZNY AI
# ==================================================
# Oto zwięzłe podsumowanie:
#
# 1.  **🟢 Główne sukcesy:**
#     FutureCorp odnotowało silne wyniki, napędzane bezprecedensowym popytem na układy AI. Przychody wzrosły o 45% r/r do 12,5 mld USD, a dochód netto o 12% r/r do 3,2 mld USD.
#
# 2.  **🔴 Główne ryzyka:**
#     Firma stoi w obliczu ograniczeń łańcucha dostaw oraz ryzyka związanego z napięciami geopolitycznymi w Azji, które mogą wpłynąć na partnerów produkcyjnych. Dodatkowo, nowy pozew o naruszenie patentów może skutkować grzywną do 500 mln USD, a koszty operacyjne znacząco wzrosły z powodu inwestycji w R&D.
#
# 3.  **⚖️ Werdykt inwestycyjny:**
#     Neutralny.

# %% [markdown]
# ## 🧠 Zadanie Domowe: Dynamiczny Analityk
#
# Obecnie nasz bot robi ogólne podsumowanie.
# Zmodyfikuj go, aby przyjmował parametr `mode`.
#
# **Zadanie:**
# 1. Napisz funkcję `analyze_custom(text, mode)`.
# 2. Jeśli `mode == "RISK"`, prompt ma brzmieć: *"Jesteś Risk Managerem. Wypisz tylko listę zagrożeń w punktach."*
# 3. Jeśli `mode == "GROWTH"`, prompt ma brzmieć: *"Jesteś Inwestorem Wzrostowym. Wypisz tylko szanse i wzrosty."*
# 4. Przetestuj oba tryby na naszym raporcie.

# %%
def analyze_custom(text, mode="GENERAL"):
    
    if mode == "RISK":
        role = "Jesteś Risk Managerem. Wypisz w punktach WSZYSTKIE zagrożenia (prawne, łańcuch dostaw, finansowe). Bądź krytyczny."
    elif mode == "GROWTH":
        role = "Jesteś Inwestorem Growth. Skup się tylko na wzroście przychodów, nowych produktach i ekspansji. Ignoruj ryzyka."
    else:
        role = "Jesteś analitykiem finansowym. Zrób ogólne podsumowanie."
        
    print(f"\n🕵️‍♂️ Tryb analizy: {mode}")
    
    response = llm.invoke([
        ("system", role),
        ("human", f"Raport:\n{text}")
    ])
    
    return response.content

# Testy
print(analyze_custom(raw_text, mode="RISK"))
print("-" * 40)
print(analyze_custom(raw_text, mode="GROWTH"))
# Out:
# 🕵️‍♂️ Tryb analizy: RISK
# Rozumiem. Jako Risk Manager, analizuję dostarczony raport FutureCorp Inc. z krytycznym spojrzeniem, identyfikując wszystkie potencjalne zagrożenia prawne, związane z łańcuchem dostaw oraz finansowe.
#
# ---
#
# **Raport Ocena Ryzyka dla FutureCorp Inc. - Q3 2024**
#
# **I. Ryzyka Prawne:**
#
# *   **Bieżący Pozew o Naruszenie Patentów:** Bezpośrednie ryzyko ze strony konkurenta, z potencjalną karą finansową do **$500M**. To nie tylko koszt kary, ale także:
#     *   Koszty sądowe i obsługi prawnej.
#     *   Rozproszenie uwagi zarządu i kluczowych pracowników.
#     *   Potencjalne negatywne skutki dla reputacji firmy, niezależnie od wyniku procesu.
#     *   Możliwość nałożenia zakazu sprzedaży produktów lub konieczności zmiany technologii, co wpłynie na przyszłe przychody i koszty R&D.
# *   **Ryzyko Przyszłych Sporów Patentowych:** Działanie w szybko rozwijającej się branży technologicznej (AI Hardware) oraz znaczące inwestycje w R&D zwiększają prawdopodobieństwo przyszłych sporów o własność intelektualną. Innowacje często prowadzą do "kolizji" patentowych.
#
# **II. Ryzyka Związane z Łańcuchem Dostaw:**
#
# *   **Utrzymujące się Wąskie Gardła w Łańcuchu Dostaw:** Mimo "unprecedented demand," firma nadal boryka się z ograniczeniami. Oznacza to:
#     *   Niewykorzystane możliwości sprzedaży i utracone przychody.
#     *   Potencjalne opóźnienia w dostawach do klientów, prowadzące do niezadowolenia, utraty lojalności i potencjalnie do renegocjacji umów lub utraty kontraktów.
#     *   Zwiększone koszty operacyjne wynikające z poszukiwania alternatywnych dostawców, przyspieszonych wysyłek czy magazynowania.
#     *   Ryzyko, że konkurenci, którzy lepiej zarządzają łańcuchem dostaw, zyskają przewagę rynkową.
# *   **Geopolityczne Napięcia w Azji:** Wysokie uzależnienie od "semiconductor fabrication partners" z Azji (co jest typowe dla branży) stwarza poważne ryzyko:
#     *   **Ryzyko koncentracji:** Prawdopodobnie FutureCorp jest zależne od niewielkiej liczby kluczowych partnerów w regionie. Zakłócenia u jednego z nich mogą sparaliżować produkcję.
#     *   **Przerwy w Produkcji/Dostawach:** Eskalacja napięć może doprowadzić do fizycznych zakłóceń, sankcji handlowych, blokad transportowych lub niestabilności gospodarczej, uniemożliwiając terminową produkcję i dostawy chipów.
#     *   **Wzrost Kosztów:** Potencjalne wzrosty cen surowców, energii, transportu, a także cła lub podatki wynikające ze zmian politycznych.
#     *   **Ryzyko Utraty Własności Intelektualnej:** W niestabilnych regionach zawsze istnieje ryzyko kradzieży technologii lub wymuszonych transferów IP.
#     *   **Brak Dywersyfikacji:** Raport nie wskazuje na strategię dywersyfikacji źródeł produkcji poza Azję, co pogłębia ryzyko.
#
# **III. Ryzyka Finansowe:**
#
# *   **Potencjalna Kara z Tytułu Pozwu Patentowego:** Bezpośredni wpływ na zysk netto i płynność finansową. Kwota do $500M to znacząca część zysku netto Q3 ($3.2B).
# *   **Znaczący Wzrost Kosztów Operacyjnych (R&D):** Chociaż inwestycje w R&D są kluczowe dla innowacji, "significantly increased operating expenses" bez natychmiastowego proporcjonalnego wzrostu przychodów może:
#     *   Presjonować marże operacyjne i zyskowność krótkoterminową (co widać po niższym wzroście zysku netto 12% vs. 45% wzrost przychodów).
#     *   Wymagać znacznego finansowania, potencjalnie obciążając płynność lub zwiększając zadłużenie.
#     *   Stwarzać ryzyko, że te inwestycje nie przyniosą oczekiwanego zwrotu w przyszłości, jeśli produkty nie znajdą odbiorców lub zostaną szybko przescignięte przez konkurencję.
# *   **Spowolnienie Wzrostu Przychodów w Q4 ("flat due to seasonal adjustments"):** Po 45% wzroście rocznym, "płaskie" przychody w kolejnym kwartale to znaczące spowolnienie.
#     *   **Ryzyko niedoszacowania przyczyn:** Czy "sezonowość" jest jedynym powodem, czy może maskuje inne, bardziej fundamentalne problemy, takie jak:
#         *   Nasycenie rynku?
#         *   Zwiększona konkurencja?
#         *   Problemy z produkcją/dostawami uniemożliwiające zaspokojenie popytu (wspomniane "supply chain constraints")?
#         *   Wyczerpanie się "unprecedented demand" na chipy AI?
#     *   Może to sugerować trudności w utrzymaniu tempa wzrostu lub wskazywać na nadmierne poleganie na jednym, choć obecnie modnym, segmencie rynku (generative AI chips).
#     *   Wpłynie negatywnie na sentyment inwestorów i potencjalnie na wycenę akcji.
# *   **Ryzyko Koncentracji Produktowej/Rynkowej:** Firma silnie bazuje na "generative AI chips". Wysoka koncentracja na jednym typie produktu lub technologii stwarza ryzyko:
#     *   Szybkiej obsolescencji technologicznej.
#     *   Nagłej zmiany preferencji rynkowych.
#     *   Intensywnej konkurencji w tej niszy.
#     *   Wszelkie negatywne zdarzenia w tym segmencie (np. pojawienie się znacznie lepszej technologii od konkurencji) mogą mieć katastrofalny wpływ na całą firmę.
# *   **Zwiększone Koszty Kapitału:** Suma powyższych ryzyk (pozew, geopolityka, spowolnienie wzrostu) może zwiększyć postrzegane ryzyko inwestycyjne FutureCorp, co może przełożyć się na wyższe koszty pozyskania kapitału w przyszłości (droższe kredyty, niższa wycena akcji).
#
# ---
#
# **Podsumowanie Krytyczne:**
#
# Raport, choć wskazuje na silne wyniki bieżące, wyraźnie sygnalizuje poważne, wzajemnie powiązane ryzyka. Największym wyzwaniem dla FutureCorp wydaje się utrzymanie dynamicznego wzrostu w obliczu chronicznych problemów z łańcuchem dostaw, rosnących napięć geopolitycznych oraz istotnego ryzyka prawnego i finansowego związanego z pozwem. Płaski outlook na Q4 po tak dynamicznym wzroście jest sygnałem ostrzegawczym, który wymaga głębszej analizy niż tylko "sezonowe korekty". Koncentracja na jednym, choć obecnie lukratywnym, segmencie AI również stanowi istotne ryzyko strategiczne.
# ----------------------------------------
#
# 🕵️‍♂️ Tryb analizy: GROWTH
# **Analiza Inwestora Growth: FutureCorp Inc. - Q3 2024**
#
# **Nasza Perspektywa: Skupienie na Wzroście Przychodów, Nowych Produktach i Ekspansji**
#
# FutureCorp Inc. dostarcza niezwykle obiecujące wyniki, które idealnie wpisują się w naszą strategię inwestowania w dynamiczny wzrost. Raport za Q3 2024 potwierdza, że spółka jest na ścieżce intensywnej ekspansji i innowacji.
#
# *   **Fenomenalny Wzrost Przychodów:** Główne dane mówią same za siebie: **przychody wzrosły o 45% rok do roku, osiągając imponujące 12.5 miliarda dolarów**. Jest to kluczowy wskaźnik siły firmy i jej zdolności do kapitalizowania na rosnącym rynku. Tak dynamiczny wzrost świadczy o skutecznej strategii rynkowej i doskonałym pozycjonowaniu produktu.
# *   **Napęd dla Przyszłych Innowacji i Produktów:** Zwiększone wydatki operacyjne, podyktowane inwestycjami w R&D, są dla nas niezwykle pozytywnym sygnałem. Świadczy to o tym, że FutureCorp aktywnie rozwija nowe technologie i produkty, budując fundamenty pod przyszłe, jeszcze większe strumienie przychodów. Agresywne inwestowanie w badania i rozwój to paliwo dla trwałego wzrostu i umacniania pozycji lidera w sektorze.
# *   **Dominacja na Rynku AI:** Niewiarygodny popyt na chipy do generatywnej sztucznej inteligencji jest głównym motorem wzrostu. FutureCorp jest kluczowym graczem w najbardziej transformacyjnym i dynamicznie rozwijającym się segmencie technologicznym, co gwarantuje ogromny potencjał ekspansji rynkowej i długoterminowego wzrostu przychodów.
# *   **Perspektywy: Konsolidacja Przed Kolejnym Skokiem:** Oczekiwanie stabilnych przychodów w Q4 z powodu czynników sezonowych nie jest dla nas powodem do obaw, lecz raczej naturalnym momentem na konsolidację. To okazja dla firmy do dalszego udoskonalania produktów i optymalizacji procesów, aby przygotować grunt pod kolejny etap przyspieszonego wzrostu w 2025 roku i później. Utrzymanie pędu innowacyjnego jest kluczowe, a intensywne R&D wskazuje, że firma jest na to gotowa.
#
# **Podsumowanie:**
# FutureCorp Inc. to podręcznikowy przykład inwestycji growth. Jej zdolność do generowania tak imponującego wzrostu przychodów w strategicznym sektorze AI, połączona z agresywnymi inwestycjami w innowacje i rozwój nowych produktów, czyni ją wysoce atrakcyjną pozycją w naszym portfelu. Skupiamy się na pędzie rynkowym, innowacjach, ekspansji i przyszłej dominacji, a FutureCorp dostarcza na wszystkich tych frontach.
